# %%
# for inline plots in jupiter
# %matplotlib inline
#import matplotlib
import matplotlib.pyplot as plt
# for latex equations
from IPython.display import Math,Latex
# for displaying images
from IPython.core.display import Image
# import seaborn
import seaborn as sns
# settings for seaborn plotting style
sns.set(color_codes = True)
# settings for seaborn plot sizes
sns.set (rc = {'figure.figsize':(5,5)})

# %%
#import uniform distribution
from scipy.stats import uniform

# %%
#random numbers from uniform distribution
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size = n, loc = start, scale = width)

# %%
ax = sns.distplot(data_uniform,
                 bins = 100,
                 kde = True,
                 color = 'skyblue',
                 hist_kws = {"linewidth": 15,'alpha':1})
ax.set(xlabel = 'Uniform Distribution', ylabel = 'Frequency')
# Out:
# <ipython-input-17-a006c943e51f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_uniform,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a006c943e51f> in <cell line: 7>()
#       5                  hist_kws = {"linewidth": 15,'alpha':1})
#       6 ax.set(xlabel = 'Uniform Distribution', ylabel = 'Frequency')
# ----> 7 [Text(0,0.5,u'Frequency'), Text(0.5,0,u'Uniform Distribution ')]
#       8
#
# NameError: name 'Text' is not defined

# %%
# Poisson Distribution
from scipy.stats import poisson
# Generate random numbers from a Poisson distribution
data_poisson = poisson.rvs(mu=3, size=10000, random_state=42)

# Create a seaborn histogram without KDE
ax = sns.distplot(data_poisson, bins=30,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15, 'alpha': 1})

# Set labels for the x-axis and y-axis
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')

# Display the plot
plt.show()
# Out:
# <ipython-input-20-3d6831b65d91>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_poisson, bins=30,

# %%
# Normal Distribution
from scipy.stats import norm

# Set seaborn plotting style and figure size
sns.set(rc={'figure.figsize': (5, 5)})

# Generate random numbers from N(0, 1)
data_normal = norm.rvs(size=10000, loc=0, scale=1)

# Create a seaborn histogram with KDE
ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15, 'alpha': 1})

# Set labels for the x-axis and y-axis
ax.set(xlabel='Normal Distribution', ylabel='Frequency')

# Display the plot
plt.show()
# Out:
# <ipython-input-21-7466315664c7>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_normal,

# %%
# Exponential distribution
from scipy.stats import expon
# Generate random numbers from an exponential distribution
data_expon = expon.rvs(scale=1, loc=0, size=1000)

# Create a seaborn histogram with KDE
ax = sns.distplot(data_expon, kde=True,
                  bins=100,
                  color='skyblue',
                  hist_kws={"linewidth": 15, 'alpha': 1})

# Set labels for the x-axis and y-axis
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')

# Display the plot
plt.show()
# Out:
# <ipython-input-22-14886b0119ce>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_expon, kde=True,
